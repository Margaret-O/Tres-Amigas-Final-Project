# %% [markdown]
# Our Project: Finding out what neighborhood in Pittsburgh is best to raise a D1 Basketball Player

# %%
import pandas as pd
import fpsnippets
from fpsnippets import geo_to_neighborhood
# %matplotlib inline

# %%
data = pd.read_csv('farmersMarket.tsv', sep= '\t' )
print(data)
# Out:
#      _id  market_id  market_type                          market_name  \
# 0   1486         21   Farm Stand                Beccari's Farm Market
# 1   1487         51  Farm Market     Carrick Citiparks Farmers Market
# 2   1488         90  Farm Market          East Liberty Farmers Market
# 3   1489         92   Farm Stand  Eichner's Farm Market & Greenhouses
# 4   1490        207  Farm Market                       Monroeville FM
# ..   ...        ...          ...                                  ...
# 66  1552        296  Farm Market             Southside Farmers Market
# 67  1553        303   Farm Stand                     Sturges Orchards
# 68  1554        317   Farm Stand                       Triple B Farms
# 69  1555        406   Farm Stand                       Janoski's Farm
# 70  1556        425  Farm Market                  Moon Farmers Market
#
#                    address1           city state  zip_code   latitude  \
# 0      5095 Thomas Run Road        Oakdale    PA     15071  40.375388
# 1     1529 Brownsville Road     Pittsburgh    PA     15210  40.391341
# 2   N Euclid Ave & Broad St     Pittsburgh    PA     15026  40.470769
# 3          285 Richard Road        Wexford    PA     15090  40.608589
# 4         2399 Tillbrook Rd    Monroeville    PA     15146  40.418362
# ..                      ...            ...   ...       ...        ...
# 66  18th and Carson Streets     Pittsburgh    PA     15203  40.428753
# 67            1726 Penn Ave     Pittsburgh    PA     15222  40.449865
# 68           823 Berry Lane    Monongahela    PA     15063  40.227675
# 69            1714 Route 30        Clinton    PA     15026  40.630862
# 70     1629 Beaver Grade Rd  Moon Township    PA     15108  40.499282
#
#     longitude         phone  phone_ext     county
# 0  -80.135377  4.122219e+09        NaN  Allegheny
# 1  -79.986603  4.124227e+09        NaN  Allegheny
# 2  -79.922862           NaN        NaN  Allegheny
# 3  -80.061099  7.249352e+09        NaN  Allegheny
# 4  -79.763612  7.245389e+09        NaN  Allegheny
# ..        ...           ...        ...        ...
# 66 -79.980545           NaN        NaN  Allegheny
# 67 -79.985696  7.247529e+09        NaN  Allegheny
# 68 -79.946589  7.242584e+09        NaN  Allegheny
# 69 -79.826371  7.248993e+09        NaN  Allegheny
# 70 -80.201288  4.122622e+09        NaN  Allegheny
#
# [71 rows x 13 columns]

# %%
print(data["latitude"])
print(data["latitude"].head())
# Out:
# 0     40.375388
# 1     40.391341
# 2     40.470769
# 3     40.608589
# 4     40.418362
#         ...
# 66    40.428753
# 67    40.449865
# 68    40.227675
# 69    40.630862
# 70    40.499282
# Name: latitude, Length: 71, dtype: float64
# 0    40.375388
# 1    40.391341
# 2    40.470769
# 3    40.608589
# 4    40.418362
# Name: latitude, dtype: float64

# %%
print(data["longitude"])
print(data["longitude"].head())
# Out:
# 0    -80.135377
# 1    -79.986603
# 2    -79.922862
# 3    -80.061099
# 4    -79.763612
#         ...
# 66   -79.980545
# 67   -79.985696
# 68   -79.946589
# 69   -79.826371
# 70   -80.201288
# Name: longitude, Length: 71, dtype: float64
# 0   -80.135377
# 1   -79.986603
# 2   -79.922862
# 3   -80.061099
# 4   -79.763612
# Name: longitude, dtype: float64

# %%
#float_result = float(result)
#result = fpsnippets.geo_to_neighborhood(data["longitude"], data["latitude"])

# %%
#try:
#    result = fpsnippets.geo_to_neighborhood(data["longitude"], data["latitude"])
#    float_result = float(result)
#    print("Conversion successful:", float_result)
#except (ValueError, TypeError) as e:
#    print("Error:", e)

# %%
#for index, row in data.iterrows():
#    latitude= str(row['latitude'])[1:]
 #   longitude = str(row['longitude'])[1:]
   # try:
    #    latitude = float(latitude)
      #  longitude = float(longitude)
  #  except:
 #       continue

# %%
for index, row in data.iterrows():
    # Convert latitude and longitude to strings
    latitude_str = str(row['latitude'])
    longitude_str = str(row['longitude'])
    latitude = float(latitude_str)
    longitude = float(longitude_str)
    # Print the converted values
    print(f"Latitude: {latitude_str}, Longitude: {longitude_str}")
    print(f"Number of rows: {len(data)}")
    # Assuming fpsnippets is a method that converts latitude and longitude to neighborhood names
    # Replace this with your actual method
    neighborhood_name = geo_to_neighborhood(latitude, longitude)

    # Print the neighborhood name
    print(f"Neighborhood: {neighborhood_name}\n")
# Out:
# Latitude: 40.3753878, Longitude: -80.1353771
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.3913414, Longitude: -79.986603
# Number of rows: 71
# Neighborhood: Carrick
#
# Latitude: 40.4707688, Longitude: -79.9228625
# Number of rows: 71
# Neighborhood: Highland Park
#
# Latitude: 40.608589, Longitude: -80.061099
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4183624, Longitude: -79.763612
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.3712883, Longitude: -80.2263223
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.6229219, Longitude: -79.900133
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.551259, Longitude: -80.0210399
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.5065105, Longitude: -79.7234442
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.3339166, Longitude: -79.8230182
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.5085289, Longitude: -79.7295836
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.606884, Longitude: -80.0887179
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4519459, Longitude: -79.983171
# Number of rows: 71
# Neighborhood: Strip District
#
# Latitude: 40.5817003, Longitude: -79.9310915
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4619437, Longitude: -79.9196037
# Number of rows: 71
# Neighborhood: East Liberty
#
# Latitude: 40.5191919, Longitude: -79.8422439
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.35776, Longitude: -79.963652
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.5375999, Longitude: -80.184694
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.471285, Longitude: -79.96358
# Number of rows: 71
# Neighborhood: Central Lawrenceville
#
# Latitude: 40.3398434, Longitude: -79.8289475
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4254803, Longitude: -80.1408716
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.443556, Longitude: -79.883681
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.582594, Longitude: -79.934791
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.3554255, Longitude: -80.0530258
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.5516087, Longitude: -80.0209421
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4504489, Longitude: -79.8908929
# Number of rows: 71
# Neighborhood: Homewood South
#
# Latitude: 40.278307, Longitude: -79.8755899
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.3404079, Longitude: -79.8272895
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4688884, Longitude: -79.9350143
# Number of rows: 71
# Neighborhood: Garfield
#
# Latitude: 40.4347923, Longitude: -79.9227336
# Number of rows: 71
# Neighborhood: Squirrel Hill South
#
# Latitude: 40.3799988, Longitude: -80.045239
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4525503, Longitude: -80.1363663
# Number of rows: 71
# Neighborhood: None
#
# Latitude: nan, Longitude: nan
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.3757792, Longitude: -79.8424543
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.443894, Longitude: -80.05627
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4893588, Longitude: -79.9030552
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.533477, Longitude: -80.035435
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4756284, Longitude: -79.7647372
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.361279, Longitude: -80.089355
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4209151, Longitude: -79.8857961
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4012136, Longitude: -79.9173288
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.399053, Longitude: -79.8631369
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.340036, Longitude: -80.0653899
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.505477, Longitude: -79.844506
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.6030221, Longitude: -79.7524571
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4962663, Longitude: -80.0569321
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4509213, Longitude: -79.8998585
# Number of rows: 71
# Neighborhood: Point Breeze North
#
# Latitude: 40.3191781, Longitude: -80.0081111
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.5375987, Longitude: -80.1847631
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.6395268, Longitude: -79.7111371
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.3712883, Longitude: -80.2263223
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.659435, Longitude: -79.745694
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.626413, Longitude: -80.079126
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.6153181, Longitude: -80.0928344
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4590954, Longitude: -79.9442895
# Number of rows: 71
# Neighborhood: Bloomfield
#
# Latitude: 40.4233586, Longitude: -80.0444059
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.6520911, Longitude: -80.0562206
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.6681675, Longitude: -79.9237499
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.312175, Longitude: -79.93862
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.5167764, Longitude: -80.030741
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4644172, Longitude: -79.9214983
# Number of rows: 71
# Neighborhood: East Liberty
#
# Latitude: 40.374029, Longitude: -80.047817
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.66388, Longitude: -79.937014
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.417691, Longitude: -79.840482
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.5128978, Longitude: -79.7632284
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4395392, Longitude: -79.9990153
# Number of rows: 71
# Neighborhood: Central Business District
#
# Latitude: 40.4287528, Longitude: -79.980545
# Number of rows: 71
# Neighborhood: South Side Flats
#
# Latitude: 40.449865, Longitude: -79.9856963
# Number of rows: 71
# Neighborhood: Strip District
#
# Latitude: 40.227675, Longitude: -79.946589
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.6308623, Longitude: -79.8263713
# Number of rows: 71
# Neighborhood: None
#
# Latitude: 40.4992819, Longitude: -80.201288
# Number of rows: 71
# Neighborhood: None
